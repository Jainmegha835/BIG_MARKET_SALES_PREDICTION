# %% [markdown]
# Big mart sales data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Test.csv')
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# 5              FDH56        9.800          Regular         0.063817
# 6              FDL48       19.350          Regular         0.082602
# 7              FDC48          NaN          Low Fat         0.015782
# 8              FDN33        6.305          Regular         0.123365
# 9              FDA36        5.985          Low Fat         0.005698
# 10             FDT44       16.600          Low Fat         0.103569
# 11             FDQ56        6.590          Low Fat         0.105811
# 12             NCC54          NaN          Low Fat         0.171079
# ...

# %%
plt.scatter(data['Item_Weight'],data['Outlet_Type'])

# %%
plt.scatter(data['Item_Fat_Content'],data['Outlet_Type'])

# %%
plt.scatter(data['Item_MRP'],data['Outlet_Type'])

# %%
import scipy.cluster.hierarchy as sch
from sklearn.neighbors import KNeighborsClassifier

# %%
x=data[['Item_Fat_Content','Item_Visibility','Outlet_Location_Type']]
y=data['Outlet_Type']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
number=LabelEncoder()
data['Item_Fat_Content']=number.fit_transform(data['Item_Fat_Content'].astype('str'))
data['Item_Fat_Content']=number.fit_transform(data['Item_Fat_Content'].astype('str'))
data.head(5)
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDW58       20.750                 1         0.007565
# 1           FDW14        8.300                 4         0.038428
# 2           NCN55       14.600                 1         0.099575
# 3           FDQ58        7.315                 1         0.015388
# 4           FDY38          NaN                 2         0.118599
#
#      Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Snack Foods  107.8622            OUT049                       1999
# 1        Dairy   87.3198            OUT017                       2007
# 2       Others  241.7538            OUT010                       1998
# 3  Snack Foods  155.0340            OUT017                       2007
# 4        Dairy  234.2300            OUT027                       1985
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type
# 0      Medium               Tier 1  Supermarket Type1
# ...

# %%
number=LabelEncoder()
data['Item_Visibility']=number.fit_transform(data['Item_Visibility'].astype('str'))
data['Item_Visibility']=number.fit_transform(data['Item_Visibility'].astype('str'))
data.head(5)
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDW58       20.750                 1             4900
# 1           FDW14        8.300                 4              796
# 2           NCN55       14.600                 1             3383
# 3           FDQ58        7.315                 1             3201
# 4           FDY38          NaN                 2             3806
#
#      Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Snack Foods  107.8622            OUT049                       1999
# 1        Dairy   87.3198            OUT017                       2007
# 2       Others  241.7538            OUT010                       1998
# 3  Snack Foods  155.0340            OUT017                       2007
# 4        Dairy  234.2300            OUT027                       1985
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type
# 0      Medium               Tier 1  Supermarket Type1
# ...

# %%
number=LabelEncoder()
data['Outlet_Location_Type']=number.fit_transform(data['Outlet_Location_Type'].astype('str'))
data['Outlet_Location_Type']=number.fit_transform(data['Outlet_Location_Type'].astype('str'))
data.head(5)
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDW58       20.750                 1             4900
# 1           FDW14        8.300                 4              796
# 2           NCN55       14.600                 1             3383
# 3           FDQ58        7.315                 1             3201
# 4           FDY38          NaN                 2             3806
#
#      Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Snack Foods  107.8622            OUT049                       1999
# 1        Dairy   87.3198            OUT017                       2007
# 2       Others  241.7538            OUT010                       1998
# 3  Snack Foods  155.0340            OUT017                       2007
# 4        Dairy  234.2300            OUT027                       1985
#
#   Outlet_Size  Outlet_Location_Type        Outlet_Type
# 0      Medium                     0  Supermarket Type1
# ...

# %%
dendrogram=sch.dendrogram(sch.linkage(x,method="ward"))
plt.title("market sales")
plt.xlabel("INPUT")
plt.ylabel("OUTPUT")
plt.show()

# %%
x1=data['Item_Fat_Content']
y1=data['Outlet_Type']

# %%
from sklearn.datasets.samples_generator import make_blobs

# %%
x1,y1=make_blobs(n_samples=500,centers=3,random_state=0,cluster_std=0.40)
plt.scatter(x1[:,0],x1[:,1],c=y,s=50,cmap="spring")

# %%
x1fit=np.linspace(-1,3.5)
plt.scatter(x1[:,0],x1[:,1],c=y,s=50,cmap="spring")
for m,b,d in [(1,0.66,0.33),(0.5,1.6,0.55),(-0.2,2.9,0.2)]:
    y1fit=m*x1fit+b
    plt.plot(x1fit,y1fit,"k")
    plt.fill_between(x1fit,y1fit-d,y1fit+d,edgecolor="none",color="#AAAAAA",alpha=0.6)
plt.xlim(-1,3.5)
plt.show()

# %%
plt.xlabel("Item_Fat_Content")
plt.ylabel("Outlet_Type")
plt.title("FAT_CONTENT VS OUTLET_TYPE")
x1,y1=make_blobs(n_samples=150,centers=2,random_state=0,cluster_std=0.40)
plt.scatter(x1[:,0],x1[:,1],c='yellow',cmap="summer")
for m,b,d in [(1,0.66,0.33),(0.5,1.6,0.55),(-0.2,2.9,0.2)]:
    y1fit=m*x1fit+b
    plt.plot(x1fit,y1fit,"orange")
    plt.fill_between(x1fit,y1fit-d,y1fit+d,edgecolor="blue",color="pink",alpha=1.0)
plt.xlim(-1,3.5)
# plt.xlim(-1,3.5)
plt.show()

# %%
x=data[['Item_Fat_Content','Item_Visibility','Outlet_Location_Type']]
y=data['Outlet_Type']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=.3, random_state=100)

# %%
x_train.shape
y_train.shape
x_test.shape
y_test.shape
# Out:
# (1705,)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
pred = knn.predict(x_test)
pred
# Out:
# array(['Supermarket Type2', 'Supermarket Type1', 'Grocery Store', ...,
#        'Supermarket Type2', 'Supermarket Type1', 'Supermarket Type1'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.6217008797653959

# %%
knn.score(x_train,y_train)
# Out:
# 0.7014587525150905

# %%
testData = [[1,4900,0]]
test = pd.DataFrame(testData)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.6217008797653959

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\RAM\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
model.score(x_train,y_train)
# Out:
# 0.8365191146881288

# %%
output = model.predict(megha)
print(output)
# Out:
# ['Supermarket Type1']
